# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import SGDClassifier 
from sklearn.metrics import f1_score, accuracy_score
from sklearn.metrics import precision_recall_fscore_support as score
from datetime import datetime

import seaborn as sns
sns.set(style="darkgrid")
#local
from tadat.pipeline import plots
from tadat.core import data, vectorizer, features, helpers, embeddings

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
def ethnicity_multi_labels(x):
    if "ASIAN" in x:
        return "ASIAN"
    elif "AFRICAN" in x:
        return "BLACK"
    elif "HISPANIC" in x:
        return "HISPANIC"
    elif "WHITE" in x:
        return "WHITE"
    elif "NATIVE" in x:
        return "OTHER"
        return "NATIVE"
    else:
        return "OTHER"

def ethnicity_binary_labels(x):
    if "ASIAN" in x or "AFRICAN" in x or "HISPANIC" in x or "NATIVE" in x: 
        return "NON-WHITE"
    elif "WHITE" in x:
        return "WHITE"
    else:
        return "OTHER"

def get_ethnicity_dataset(df, path_out=None):
    df["ETHNICITY_LABEL"] = df["ETHNICITY"].apply(lambda x:ethnicity_binary_labels(x))
    df_ethnicity = df[["ETHNICITY_LABEL","TEXT"]]
    if path_out:
        df_ethnicity.to_csv(path_out,index=False, sep="\t", header=False)
        
    return df_ethnicity

def get_mortality_dataset(df, path_out=None):
    df["EXPIRE"] = df["HOSPITAL_EXPIRE_FLAG"]
    df_mortality = df[["EXPIRE","TEXT","GENDER","ETHNICITY_LABEL","ETHNICITY_BINARY"]]
    if path_out:
        df_mortality.to_csv(path_out,index=False, sep="\t", header=False)
    return df_mortality

def get_readmissions_dataset(mimic_path, patients_df, path_out=None):
    admissions_df = pd.read_csv(mimic_path+"ADMISSIONS.CSV.gz")
    data = []
    READMISSION_DELTA = float("inf")
    for _, patient in patients_df.iterrows():
        adm = admissions_df[admissions_df["SUBJECT_ID"] == patient["SUBJECT_ID"]]
        if len(adm) > 1:
            admission_times = list(adm.sort_values("ADMITTIME")["ADMITTIME"])
            for i in range(len(admission_times)-1):
                d1 = admission_times[i]
                d2 = admission_times[i+1]
                d1 = datetime.strptime(d1, "%Y-%m-%d %H:%M:%S")
                d2 = datetime.strptime(d2, "%Y-%m-%d %H:%M:%S")
                delta = d2 - d1
                if delta.days < READMISSION_DELTA:
                    data.append([1,patient["TEXT"],patient["GENDER"]])
                    break             
        else:
            data.append([0,patient["TEXT"],patient["GENDER"], 
                           patient["ETHNICITY_LABEL"], patient["ETHNICITY_BINARY"]])
    readm_df = pd.DataFrame(data, columns=["READMISSION","TEXT","GENDER","ETHNICITY_LABEL","ETHNICITY_BINARY"])
    if path_out:
        readm_df.to_csv(path_out,index=False, sep="\t", header=False)    
    return readm_df
    

def extract_patients(mimic_path, sample_size=None, path_out=None):
    all_notes = pd.read_csv(mimic_path+"NOTEEVENTS.CSV.gz")
    all_patients = pd.read_csv(mimic_path+"PATIENTS.CSV.gz")
    all_admissions = pd.read_csv(mimic_path+"ADMISSIONS.CSV.gz")
    #filter relevant columns
    notes = all_notes[["TEXT"]]
    notes["TEXT"] = notes["TEXT"].apply(lambda x: x.replace("\n","").replace("\t","").lower())
    patients = all_patients[["SUBJECT_ID","GENDER"]]
    admissions = all_admissions[["INSURANCE","ETHNICITY","HOSPITAL_EXPIRE_FLAG"]]
    #subsample?
    if sample_size:        
        patients = patients[:sample_size]
    #join dataframes
    patients = patients.join(admissions, how="inner", on="SUBJECT_ID",rsuffix="A_")
    patients = patients.join(notes, how="inner", on="SUBJECT_ID",rsuffix="N_")
    patients["ETHNICITY_LABEL"] = patients["ETHNICITY"].apply(lambda x:ethnicity_multi_labels(x))
    patients["ETHNICITY_BINARY"] = patients["ETHNICITY"].apply(lambda x:ethnicity_binary_labels(x))
    
    if path_out:
        patients.to_csv(path_out,index=False, sep="\t", header=False)    
    
    return patients

def subsample(df, label, ratio):
    RATIO = 1
    positive_size = df.groupby(label).size()[1]
    negative_size = int(positive_size * RATIO)
    all_size = positive_size + negative_size
    print("{} > Pos: {}/{} | Neg: {}/{}".format(label, positive_size, all_size,
                                                       negative_size,all_size))

    df_neg = df[df[label] == 0].head(negative_size)
    df_pos = df[df[label] == 1]
    df_all = df_neg.append(df_pos, ignore_index=True)
    return df_all

# %%
raw_data_path = "/Users/samir/Dev/resources/datasets/MIMIC/full/"
out_data_path = "/Users/samir/Dev/projects/MIMIC/DATA/input/"

# %% [markdown]
# ## Extract Data

# %%
# PATIENT_SAMPLE_SIZE = 10000
# mini_patients = extract_patients(raw_data_path, PATIENT_SAMPLE_SIZE,out_data_path+"mini_patients.csv")
# mini_patients
col_names = ["SUBJECT_ID","GENDER","INSURANCE","ETHNICITY","HOSPITAL_EXPIRE_FLAG","TEXT","ETHNICITY_LABEL","ETHNICITY_BINARY"]
mini_patients = pd.read_csv(out_data_path+"mini_patients.csv", header=None, 
                            sep="\t", names=col_names)
mini_patients
# Out:
#       SUBJECT_ID GENDER INSURANCE               ETHNICITY  \
# 0            249      F  Medicaid  BLACK/AFRICAN AMERICAN
# 1            250      F  Medicare   UNKNOWN/NOT SPECIFIED
# 2            251      M  Medicaid  BLACK/AFRICAN AMERICAN
# 3            252      M  Medicare                   OTHER
# 4            253      F   Private      HISPANIC OR LATINO
# ...          ...    ...       ...                     ...
# 9995       11012      M   Private                   WHITE
# 9996       11013      F  Medicare   UNKNOWN/NOT SPECIFIED
# 9997       11014      M  Medicare   UNKNOWN/NOT SPECIFIED
# 9998       11015      M   Private                   WHITE
# 9999       11016      M   Private                   WHITE
#
#       HOSPITAL_EXPIRE_FLAG                                               TEXT  \
# 0                        0  admission date:  [**2149-6-2**]       discharg...
# 1                        0  admission date:  [**2149-9-2**]       discharg...
# 2                        0  admission date:  [**2193-1-8**]              d...
# 3                        0  admission date:  [**2133-9-3**]              d...
# 4                        0  admission date:  [**2103-8-16**]     discharge...
# ...                    ...                                                ...
# 9995                     0  admission date:  [**2154-2-7**]              d...
# 9996                     0  admission date:  [**2103-12-16**]             ...
# 9997                     0  admission date:  [**2104-2-4**]              d...
# 9998                     0  admission date:  [**2105-7-10**]              ...
# 9999                     0  admission date:  [**2105-10-3**]              ...
#
#      ETHNICITY_LABEL ETHNICITY_BINARY
# 0              BLACK        NON-WHITE
# 1              OTHER            OTHER
# 2              BLACK        NON-WHITE
# 3              OTHER            OTHER
# 4           HISPANIC        NON-WHITE
# ...              ...              ...
# 9995           WHITE            WHITE
# 9996           OTHER            OTHER
# 9997           OTHER            OTHER
# 9998           WHITE            WHITE
# 9999           WHITE            WHITE
#
# [10000 rows x 8 columns]

# %%
df_mortality = get_mortality_dataset(mini_patients, out_data_path+"mini_mortality.csv")
df_mortality
# Out:
#       EXPIRE                                               TEXT GENDER  \
# 0          0  admission date:  [**2149-6-2**]       discharg...      F
# 1          0  admission date:  [**2149-9-2**]       discharg...      F
# 2          0  admission date:  [**2193-1-8**]              d...      M
# 3          0  admission date:  [**2133-9-3**]              d...      M
# 4          0  admission date:  [**2103-8-16**]     discharge...      F
# ...      ...                                                ...    ...
# 9995       0  admission date:  [**2154-2-7**]              d...      M
# 9996       0  admission date:  [**2103-12-16**]             ...      F
# 9997       0  admission date:  [**2104-2-4**]              d...      M
# 9998       0  admission date:  [**2105-7-10**]              ...      M
# 9999       0  admission date:  [**2105-10-3**]              ...      M
#
#      ETHNICITY_LABEL ETHNICITY_BINARY
# 0              BLACK        NON-WHITE
# 1              OTHER            OTHER
# 2              BLACK        NON-WHITE
# 3              OTHER            OTHER
# 4           HISPANIC        NON-WHITE
# ...              ...              ...
# 9995           WHITE            WHITE
# 9996           OTHER            OTHER
# 9997           OTHER            OTHER
# 9998           WHITE            WHITE
# 9999           WHITE            WHITE
#
# [10000 rows x 5 columns]

# %%
mimic_path = "/Users/samir/Dev/resources/datasets/MIMIC/full/"
df_readm = get_readmissions_dataset(mimic_path, mini_patients, path_out=out_data_path+"/mini_readmissions.csv")
df_readm
# Out:
#       READMISSION                                               TEXT GENDER  \
# 0               1  admission date:  [**2149-6-2**]       discharg...      F
# 1               0  admission date:  [**2149-9-2**]       discharg...      F
# 2               0  admission date:  [**2193-1-8**]              d...      M
# 3               1  admission date:  [**2133-9-3**]              d...      M
# 4               0  admission date:  [**2103-8-16**]     discharge...      F
# ...           ...                                                ...    ...
# 9995            0  admission date:  [**2154-2-7**]              d...      M
# 9996            0  admission date:  [**2103-12-16**]             ...      F
# 9997            0  admission date:  [**2104-2-4**]              d...      M
# 9998            0  admission date:  [**2105-7-10**]              ...      M
# 9999            0  admission date:  [**2105-10-3**]              ...      M
#
#      ETHNICITY_LABEL ETHNICITY_BINARY
# 0               None             None
# 1              OTHER            OTHER
# 2              BLACK        NON-WHITE
# 3               None             None
# 4           HISPANIC        NON-WHITE
# ...              ...              ...
# 9995           WHITE            WHITE
# 9996           OTHER            OTHER
# 9997           OTHER            OTHER
# 9998           WHITE            WHITE
# 9999           WHITE            WHITE
#
# [10000 rows x 5 columns]

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))
df_ag = df_readm.groupby("READMISSION").size()/df_readm.groupby("READMISSION").size().sum()
df_ag.plot(ax=ax[0],kind="bar", title="Readmissions", rot=0)

df_mg = df_mortality.groupby("EXPIRE").size()/df_mortality.groupby("EXPIRE").size().sum()
df_mg.plot(ax=ax[1],kind="bar", title="Hospital Deaths", rot=0)
plt.tight_layout()

# %%
#subsample majority class (negative)
df_readm_balanced = subsample(df_readm,"READMISSION",1)
df_mortality_balanced = subsample(df_mortality,"EXPIRE",1)
#save data
df_readm_balanced.to_csv(out_data_path+"/mini_readmissions_balanced.csv",index=False, sep="\t", header=False)
df_mortality_balanced.to_csv(out_data_path+"/mini_mortality_balanced.csv",index=False, sep="\t", header=False)
# Out:
# READMISSION > Pos: 1696/3392 | Neg: 1696/3392
# EXPIRE > Pos: 1001/2002 | Neg: 1001/2002

# %% [markdown]
# ## Read Data

# %%
df_mortality = pd.read_csv(out_data_path+"mini_mortality_balanced.csv",sep="\t", header=None, names=["EXPIRE","TEXT","GENDER","ETHNICITY_LABEL","ETHNICITY_BINARY"])
df_mortality
# Out:
#       EXPIRE                                               TEXT GENDER  \
# 0          0  admission date:  [**2149-6-2**]       discharg...      F
# 1          0  admission date:  [**2149-9-2**]       discharg...      F
# 2          0  admission date:  [**2193-1-8**]              d...      M
# 3          0  admission date:  [**2133-9-3**]              d...      M
# 4          0  admission date:  [**2103-8-16**]     discharge...      F
# ...      ...                                                ...    ...
# 1997       1  admission date:  [**2190-5-22**]              ...      M
# 1998       1  admission date:  [**2118-7-29**]              ...      F
# 1999       1  admission date:  [**2114-5-24**]       dischar...      F
# 2000       1  admission date:  [**2152-9-22**]              ...      F
# 2001       1  admission date:  [**2190-3-8**]              d...      M
#
#      ETHNICITY_LABEL ETHNICITY_BINARY
# 0              BLACK        NON-WHITE
# 1              OTHER            OTHER
# 2              BLACK        NON-WHITE
# 3              OTHER            OTHER
# 4           HISPANIC        NON-WHITE
# ...              ...              ...
# 1997           OTHER            OTHER
# 1998           OTHER            OTHER
# 1999           WHITE            WHITE
# 2000           OTHER            OTHER
# 2001           ASIAN        NON-WHITE
#
# [2002 rows x 5 columns]

# %%
df_readmission = pd.read_csv(out_data_path+"mini_readmissions_balanced.csv",sep="\t", header=None, names=["READMISSION","TEXT","GENDER","ETHNICITY_LABEL","ETHNICITY_BINARY"])
df_readmission
# Out:
#       READMISSION                                               TEXT GENDER  \
# 0               0  admission date:  [**2149-9-2**]       discharg...      F
# 1               0  admission date:  [**2193-1-8**]              d...      M
# 2               0  admission date:  [**2103-8-16**]     discharge...      F
# 3               0  admission date:  [**2196-4-27**]     discharge...      M
# 4               0  admission date:  [**2158-1-5**]              d...      F
# ...           ...                                                ...    ...
# 3387            1  admission date:  [**2175-6-2**]     discharge ...      M
# 3388            1  admission date:  [**2148-4-4**]              d...      F
# 3389            1  admission date:  [**2135-4-10**]              ...      F
# 3390            1  admission date:  [**2183-5-9**]              d...      M
# 3391            1  admission date:  [**2184-10-27**]             ...      F
#
#      ETHNICITY_LABEL ETHNICITY_BINARY
# 0              OTHER            OTHER
# 1              BLACK        NON-WHITE
# 2           HISPANIC        NON-WHITE
# 3              OTHER            OTHER
# 4              OTHER            OTHER
# ...              ...              ...
# 3387             NaN              NaN
# 3388             NaN              NaN
# 3389             NaN              NaN
# 3390             NaN              NaN
# 3391             NaN              NaN
#
# [3392 rows x 5 columns]

# %%
df_mortality.groupby("GENDER").size()
# Out:
# GENDER
# F     858
# M    1144
# dtype: int64

# %%
df_readmission.groupby("GENDER").size()
# Out:
# GENDER
# F    1477
# M    1915
# dtype: int64

# %% [markdown]
# ## Analytics

# %%
def vectorize_data(train_split, test_split_M, test_split_F):
    #vectorize instances
    train_X = data.getX(train_split)
    test_X_M = data.getX(test_split_M)
    test_X_F = data.getX(test_split_F)
    
    train_X, word_vocab = vectorizer.docs2idx(train_X)
    test_X_M,_ = vectorizer.docs2idx(test_X_M, word_vocab)
    test_X_F,_ = vectorizer.docs2idx(test_X_F, word_vocab)
    #vectorize labels
    train_Y = data.getY(train_split)
    test_Y_M = data.getY(test_split_M) 
    test_Y_F = data.getY(test_split_F)    
    label_vocab = vectorizer.get_labels_vocab(train_Y+test_Y_M+test_Y_F)
    train_Y,_ = vectorizer.label2idx(train_Y, label_vocab)
    test_Y_M,_ = vectorizer.label2idx(test_Y_M, label_vocab)
    test_Y_F,_ = vectorizer.label2idx(test_Y_F, label_vocab)
    
    return train_X, train_Y, test_X_M, test_Y_M, test_X_F, test_Y_F, word_vocab, label_vocab

def get_features(data, vocab_size, feature_type, word_vectors=None):
    if feature_type == "BOW-bin":
        X = features.BOW(data, vocab_size,sparse=True)
    elif feature_type == "BOW-freq":
        X = features.BOW_freq(data, vocab_size,sparse=True)
    elif feature_type == "BOE-bin":
        X = features.BOE(data, word_vectors,"bin")
    elif feature_type == "BOE-sum": 
        X = features.BOE(data, word_vectors,"sum")
    else:
        raise NotImplementedError
    return X
    

def evaluate_classifier(X_train, Y_train, X_test, Y_test,
                   labels, model_name, random_seed=1234, res_path=None):
    model = SGDClassifier(random_state=random_seed)
    model.fit(X_train,Y_train)
    Y_hat = model.predict(X_test)
    microF1 = f1_score(Y_test, Y_hat, average="micro") 
    macroF1 = f1_score(Y_test, Y_hat, average="macro") 
    acc = accuracy_score(Y_test, Y_hat)
    precision, recall, fscore, support = score(Y_test, Y_hat)

    res = {"model":model_name, \
            "seed":random_seed, \
            "acc":round(acc,3), \
            "microF1":round(microF1,3), \
            "macroF1":round(macroF1,3)
            }

    for l, i in labels.items():
        try:
            fs = round(fscore[i],3)
        except IndexError:
            fs = 0
        res["{}-f1".format(l)] = fs
    helpers.print_results(res)
    if res_path is not None:
        cols = ["dataset", "model", "acc", "avgF1"]
        # helpers.save_results(res, res_path, sep="\t", columns=cols)
        helpers.save_results(res, res_path, sep="\t")
    return res

def get_deltas(results_M, results_F):
    #resuts
    df_M = pd.DataFrame(results_M)
    df_F = pd.DataFrame(results_F)
#     from pdb import set_trace; set_trace()
    #compute deltas
    df_delta = df_M.sub(df_F.iloc[:,2:])
    df_delta["model"] = df_M["model"]
    df_delta["seed"] = df_M["seed"]   
    
    #transform results into "long format"
    df_delta_long = df_delta.melt(id_vars=["seed","model"], value_vars=["microF1","macroF1","0-f1","1-f1"], 
                                        var_name="metric", value_name="delta")
    return df_delta, df_delta_long

def run(df, x_label, y_label, feature_type, target_label, target_value, split=0.8):
    #split into training and test sets
    train_split, test_split = data.shuffle_split_idx(df[y_label], split)
    df_train = df.iloc[train_split,:]
    df_test = df.iloc[test_split,:]
    df_test_M = df_test[df_test[target_label] == target_value]
    df_test_F = df_test[df_test[target_label] != target_value]
    
    print("M: {} | F: {}".format(len(df_test_M),len(df_test_F)))
    #transform the data into the right format
    train = data.read_dataframe(df_train, x_label, y_label)
    test_M = data.read_dataframe(df_test_M, x_label, y_label)
    test_F = data.read_dataframe(df_test_F, x_label, y_label)
    
    #get vectorized train/test data 
    train_X, train_Y, test_X_M, test_Y_M, test_X_F, test_Y_F, word_vocab, label_vocab = vectorize_data(train, test_M, test_F)
    #extract features
    train_feats = get_features(train_X, len(word_vocab), feature_type)
    test_feats_M = get_features(test_X_M, len(word_vocab), feature_type)
    test_feats_F = get_features(test_X_F, len(word_vocab), feature_type)

    #train/test classifier for each random seed
    random_seeds = list(range(20))
    results_m = []
    results_f = []
    for r in random_seeds:
        print("[running seed: {}]".format(r))
        res_m = evaluate_classifier(train_feats, train_Y, test_feats_M, test_Y_M, label_vocab, feature_type, r)
        results_m.append(res_m)
        res_f = evaluate_classifier(train_feats, train_Y, test_feats_F, test_Y_F, label_vocab, feature_type, r)
        results_f.append(res_f)
    return results_m, results_f

# %% [markdown]
# ## Mortality

# %%
df = df_mortality
x_label = "TEXT"
y_label = "EXPIRE"

results_BOW_M, results_BOW_F = run(df, x_label, y_label, "BOW-bin", "GENDER", "F", split=0.8)
results_BOW_freq_M, results_BOW_freq_F = run(df, x_label, y_label, "BOW-freq", "GENDER", "F", split=0.8)
# Out:
# M: 162 | F: 240
# /Users/samir/anaconda3/lib/python3.6/site-packages/scipy/sparse/lil.py:512: FutureWarning: future versions will not create a writeable array from broadcast_array. Set the writable flag explicitly to avoid this warning.
#   if not i.flags.writeable or i.dtype not in (np.int32, np.int64):
# /Users/samir/anaconda3/lib/python3.6/site-packages/scipy/sparse/lil.py:514: FutureWarning: future versions will not create a writeable array from broadcast_array. Set the writable flag explicitly to avoid this warning.
#   if not j.flags.writeable or j.dtype not in (np.int32, np.int64):
# /Users/samir/anaconda3/lib/python3.6/site-packages/scipy/sparse/lil.py:518: FutureWarning: future versions will not create a writeable array from broadcast_array. Set the writable flag explicitly to avoid this warning.
#   if not x.flags.writeable:
# (sparse BOW)
# (sparse BOW)
# (sparse BOW)
# [running seed: 0]
# ** model: BOW-bin| seed: 0| acc: 0.488| microF1: 0.488| macroF1: 0.484| 0-f1: 0.443| 1-f1: 0.526|
# ** model: BOW-bin| seed: 0| acc: 0.5| microF1: 0.5| macroF1: 0.5| 0-f1: 0.496| 1-f1: 0.504|
# [running seed: 1]
# ** model: BOW-bin| seed: 1| acc: 0.531| microF1: 0.531| macroF1: 0.525| 0-f1: 0.472| 1-f1: 0.578|
# ** model: BOW-bin| seed: 1| acc: 0.538| microF1: 0.538| macroF1: 0.537| 0-f1: 0.519| 1-f1: 0.554|
# [running seed: 2]
# ** model: BOW-bin| seed: 2| acc: 0.543| microF1: 0.543| macroF1: 0.481| 0-f1: 0.302| 1-f1: 0.661|
# ** model: BOW-bin| seed: 2| acc: 0.496| microF1: 0.496| macroF1: 0.438| 0-f1: 0.258| 1-f1: 0.618|
# [running seed: 3]
# ** model: BOW-bin| seed: 3| acc: 0.537| microF1: 0.537| macroF1: 0.502| 0-f1: 0.37| 1-f1: 0.634|
# ** model: BOW-bin| seed: 3| acc: 0.479| microF1: 0.479| macroF1: 0.443| 0-f1: 0.302| 1-f1: 0.585|
# [running seed: 4]
# /Users/samir/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# ** model: BOW-bin| seed: 4| acc: 0.537| microF1: 0.537| macroF1: 0.536| 0-f1: 0.561| 1-f1: 0.51|
# ** model: BOW-bin| seed: 4| acc: 0.496| microF1: 0.496| macroF1: 0.493| 0-f1: 0.529| 1-f1: 0.457|
# [running seed: 5]
# ** model: BOW-bin| seed: 5| acc: 0.549| microF1: 0.549| macroF1: 0.547| 0-f1: 0.517| 1-f1: 0.578|
# ** model: BOW-bin| seed: 5| acc: 0.479| microF1: 0.479| macroF1: 0.479| 0-f1: 0.486| 1-f1: 0.473|
# [running seed: 6]
# ** model: BOW-bin| seed: 6| acc: 0.488| microF1: 0.488| macroF1: 0.483| 0-f1: 0.435| 1-f1: 0.531|
# ** model: BOW-bin| seed: 6| acc: 0.517| microF1: 0.517| macroF1: 0.517| 0-f1: 0.508| 1-f1: 0.525|
# [running seed: 7]
# ** model: BOW-bin| seed: 7| acc: 0.543| microF1: 0.543| macroF1: 0.481| 0-f1: 0.302| 1-f1: 0.661|
# ** model: BOW-bin| seed: 7| acc: 0.467| microF1: 0.467| macroF1: 0.388| 0-f1: 0.169| 1-f1: 0.607|
# [running seed: 8]
# ** model: BOW-bin| seed: 8| acc: 0.512| microF1: 0.512| macroF1: 0.498| 0-f1: 0.415| 1-f1: 0.582|
# ** model: BOW-bin| seed: 8| acc: 0.483| microF1: 0.483| macroF1: 0.477| 0-f1: 0.421| 1-f1: 0.534|
# [running seed: 9]
# ** model: BOW-bin| seed: 9| acc: 0.519| microF1: 0.519| macroF1: 0.516| 0-f1: 0.48| 1-f1: 0.552|
# ** model: BOW-bin| seed: 9| acc: 0.5| microF1: 0.5| macroF1: 0.5| 0-f1: 0.487| 1-f1: 0.512|
# [running seed: 10]
# ** model: BOW-bin| seed: 10| acc: 0.519| microF1: 0.519| macroF1: 0.508| 0-f1: 0.435| 1-f1: 0.581|
# ** model: BOW-bin| seed: 10| acc: 0.483| microF1: 0.483| macroF1: 0.48| 0-f1: 0.436| 1-f1: 0.523|
# [running seed: 11]
# ** model: BOW-bin| seed: 11| acc: 0.549| microF1: 0.549| macroF1: 0.549| 0-f1: 0.529| 1-f1: 0.568|
# ** model: BOW-bin| seed: 11| acc: 0.471| microF1: 0.471| macroF1: 0.471| 0-f1: 0.477| 1-f1: 0.464|
# [running seed: 12]
# ** model: BOW-bin| seed: 12| acc: 0.494| microF1: 0.494| macroF1: 0.493| 0-f1: 0.474| 1-f1: 0.512|
# ** model: BOW-bin| seed: 12| acc: 0.45| microF1: 0.45| macroF1: 0.45| 0-f1: 0.459| 1-f1: 0.441|
# [running seed: 13]
# ** model: BOW-bin| seed: 13| acc: 0.512| microF1: 0.512| macroF1: 0.509| 0-f1: 0.47| 1-f1: 0.549|
# ** model: BOW-bin| seed: 13| acc: 0.488| microF1: 0.488| macroF1: 0.486| 0-f1: 0.458| 1-f1: 0.514|
# [running seed: 14]
# ** model: BOW-bin| seed: 14| acc: 0.562| microF1: 0.562| macroF1: 0.529| 0-f1: 0.403| 1-f1: 0.654|
# ** model: BOW-bin| seed: 14| acc: 0.479| microF1: 0.479| macroF1: 0.46| 0-f1: 0.359| 1-f1: 0.561|
# [running seed: 15]
# ** model: BOW-bin| seed: 15| acc: 0.531| microF1: 0.531| macroF1: 0.509| 0-f1: 0.406| 1-f1: 0.612|
# ** model: BOW-bin| seed: 15| acc: 0.475| microF1: 0.475| macroF1: 0.458| 0-f1: 0.364| 1-f1: 0.553|
# [running seed: 16]
# ** model: BOW-bin| seed: 16| acc: 0.543| microF1: 0.543| macroF1: 0.543| 0-f1: 0.543| 1-f1: 0.543|
# ** model: BOW-bin| seed: 16| acc: 0.488| microF1: 0.488| macroF1: 0.487| 0-f1: 0.494| 1-f1: 0.481|
# [running seed: 17]
# ** model: BOW-bin| seed: 17| acc: 0.481| microF1: 0.481| macroF1: 0.436| 0-f1: 0.596| 1-f1: 0.276|
# ** model: BOW-bin| seed: 17| acc: 0.508| microF1: 0.508| macroF1: 0.476| 0-f1: 0.607| 1-f1: 0.344|
# [running seed: 18]
# ** model: BOW-bin| seed: 18| acc: 0.525| microF1: 0.525| macroF1: 0.513| 0-f1: 0.438| 1-f1: 0.588|
# ** model: BOW-bin| seed: 18| acc: 0.504| microF1: 0.504| macroF1: 0.5| 0-f1: 0.452| 1-f1: 0.548|
# [running seed: 19]
# ** model: BOW-bin| seed: 19| acc: 0.543| microF1: 0.543| macroF1: 0.541| 0-f1: 0.513| 1-f1: 0.57|
# ** model: BOW-bin| seed: 19| acc: 0.483| microF1: 0.483| macroF1: 0.483| 0-f1: 0.496| 1-f1: 0.47|
# M: 162 | F: 240
# (sparse BOW)
# (sparse BOW)
# (sparse BOW)
# [running seed: 0]
# ** model: BOW-freq| seed: 0| acc: 0.537| microF1: 0.537| macroF1: 0.427| 0-f1: 0.176| 1-f1: 0.678|
# ** model: BOW-freq| seed: 0| acc: 0.492| microF1: 0.492| macroF1: 0.38| 0-f1: 0.116| 1-f1: 0.643|
# [running seed: 1]
# ** model: BOW-freq| seed: 1| acc: 0.519| microF1: 0.519| macroF1: 0.341| 0-f1: 0.0| 1-f1: 0.683|
# ** model: BOW-freq| seed: 1| acc: 0.488| microF1: 0.488| macroF1: 0.328| 0-f1: 0.0| 1-f1: 0.655|
# [running seed: 2]
# ** model: BOW-freq| seed: 2| acc: 0.494| microF1: 0.494| macroF1: 0.486| 0-f1: 0.423| 1-f1: 0.549|
# ** model: BOW-freq| seed: 2| acc: 0.421| microF1: 0.421| macroF1: 0.411| 0-f1: 0.335| 1-f1: 0.487|
# [running seed: 3]
# /Users/samir/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/samir/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/samir/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/samir/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ** model: BOW-freq| seed: 3| acc: 0.512| microF1: 0.512| macroF1: 0.339| 0-f1: 0.0| 1-f1: 0.678|
# ** model: BOW-freq| seed: 3| acc: 0.492| microF1: 0.492| macroF1: 0.344| 0-f1: 0.032| 1-f1: 0.655|
# [running seed: 4]
# ** model: BOW-freq| seed: 4| acc: 0.457| microF1: 0.457| macroF1: 0.422| 0-f1: 0.279| 1-f1: 0.564|
# ** model: BOW-freq| seed: 4| acc: 0.496| microF1: 0.496| macroF1: 0.468| 0-f1: 0.346| 1-f1: 0.59|
# [running seed: 5]
# ** model: BOW-freq| seed: 5| acc: 0.475| microF1: 0.475| macroF1: 0.412| 0-f1: 0.22| 1-f1: 0.605|
# ** model: BOW-freq| seed: 5| acc: 0.417| microF1: 0.417| macroF1: 0.388| 0-f1: 0.255| 1-f1: 0.521|
# [running seed: 6]
# ** model: BOW-freq| seed: 6| acc: 0.519| microF1: 0.519| macroF1: 0.506| 0-f1: 0.585| 1-f1: 0.426|
# ** model: BOW-freq| seed: 6| acc: 0.521| microF1: 0.521| macroF1: 0.488| 0-f1: 0.618| 1-f1: 0.358|
# [running seed: 7]
# ** model: BOW-freq| seed: 7| acc: 0.525| microF1: 0.525| macroF1: 0.433| 0-f1: 0.206| 1-f1: 0.661|
# ** model: BOW-freq| seed: 7| acc: 0.467| microF1: 0.467| macroF1: 0.375| 0-f1: 0.135| 1-f1: 0.614|
# [running seed: 8]
# ** model: BOW-freq| seed: 8| acc: 0.494| microF1: 0.494| macroF1: 0.369| 0-f1: 0.65| 1-f1: 0.089|
# ** model: BOW-freq| seed: 8| acc: 0.533| microF1: 0.533| macroF1: 0.403| 0-f1: 0.682| 1-f1: 0.125|
# [running seed: 9]
# ** model: BOW-freq| seed: 9| acc: 0.5| microF1: 0.5| macroF1: 0.49| 0-f1: 0.417| 1-f1: 0.562|
# ** model: BOW-freq| seed: 9| acc: 0.454| microF1: 0.454| macroF1: 0.448| 0-f1: 0.391| 1-f1: 0.506|
# [running seed: 10]
# ** model: BOW-freq| seed: 10| acc: 0.494| microF1: 0.494| macroF1: 0.486| 0-f1: 0.549| 1-f1: 0.423|
# ** model: BOW-freq| seed: 10| acc: 0.533| microF1: 0.533| macroF1: 0.508| 0-f1: 0.619| 1-f1: 0.398|
# [running seed: 11]
# ** model: BOW-freq| seed: 11| acc: 0.481| microF1: 0.481| macroF1: 0.417| 0-f1: 0.222| 1-f1: 0.611|
# ** model: BOW-freq| seed: 11| acc: 0.421| microF1: 0.421| macroF1: 0.391| 0-f1: 0.257| 1-f1: 0.526|
# [running seed: 12]
# ** model: BOW-freq| seed: 12| acc: 0.475| microF1: 0.475| macroF1: 0.322| 0-f1: 0.644| 1-f1: 0.0|
# ** model: BOW-freq| seed: 12| acc: 0.512| microF1: 0.512| macroF1: 0.346| 0-f1: 0.676| 1-f1: 0.017|
# [running seed: 13]
# ** model: BOW-freq| seed: 13| acc: 0.494| microF1: 0.494| macroF1: 0.445| 0-f1: 0.281| 1-f1: 0.61|
# ** model: BOW-freq| seed: 13| acc: 0.467| microF1: 0.467| macroF1: 0.442| 0-f1: 0.326| 1-f1: 0.559|
# [running seed: 14]
# ** model: BOW-freq| seed: 14| acc: 0.519| microF1: 0.519| macroF1: 0.353| 0-f1: 0.025| 1-f1: 0.68|
# ** model: BOW-freq| seed: 14| acc: 0.471| microF1: 0.471| macroF1: 0.327| 0-f1: 0.016| 1-f1: 0.638|
# [running seed: 15]
# ** model: BOW-freq| seed: 15| acc: 0.506| microF1: 0.506| macroF1: 0.347| 0-f1: 0.024| 1-f1: 0.669|
# ** model: BOW-freq| seed: 15| acc: 0.488| microF1: 0.488| macroF1: 0.335| 0-f1: 0.016| 1-f1: 0.654|
# [running seed: 16]
# ** model: BOW-freq| seed: 16| acc: 0.5| microF1: 0.5| macroF1: 0.389| 0-f1: 0.649| 1-f1: 0.129|
# ** model: BOW-freq| seed: 16| acc: 0.512| microF1: 0.512| macroF1: 0.397| 0-f1: 0.661| 1-f1: 0.133|
# [running seed: 17]
# ** model: BOW-freq| seed: 17| acc: 0.5| microF1: 0.5| macroF1: 0.486| 0-f1: 0.571| 1-f1: 0.4|
# ** model: BOW-freq| seed: 17| acc: 0.562| microF1: 0.562| macroF1: 0.532| 0-f1: 0.651| 1-f1: 0.413|
# [running seed: 18]
# ** model: BOW-freq| seed: 18| acc: 0.475| microF1: 0.475| macroF1: 0.472| 0-f1: 0.514| 1-f1: 0.43|
# ** model: BOW-freq| seed: 18| acc: 0.525| microF1: 0.525| macroF1: 0.519| 0-f1: 0.571| 1-f1: 0.467|
# [running seed: 19]
# ** model: BOW-freq| seed: 19| acc: 0.537| microF1: 0.537| macroF1: 0.522| 0-f1: 0.436| 1-f1: 0.607|
# ** model: BOW-freq| seed: 19| acc: 0.5| microF1: 0.5| macroF1: 0.496| 0-f1: 0.45| 1-f1: 0.542|

# %% [markdown]
# ## Results

# %%
#results
df_bb_delta, df_bb_delta_long = get_deltas(results_BOW_M,results_BOW_F)
df_bf_delta, df_bf_delta_long = get_deltas(results_BOW_freq_M,results_BOW_freq_F)

# %% [markdown]
# ## Plots

# %%
fig, ax = plt.subplots(1,2, sharey=True, figsize=(15,5))
LIM = 0.25
plots.plot_df(df=df_bb_delta,ax=ax[0],x="seed",ys=["microF1","macroF1","1-f1","0-f1"], annotation_size=10, max_y=LIM, min_y=-LIM)
plots.plot_df(df=df_bf_delta,ax=ax[1],x="seed",ys=["microF1","macroF1","1-f1","0-f1"], annotation_size=10, max_y=LIM, min_y=-LIM)

ax[0].set_title("bow-bin Delta")
ax[1].set_title("bow-freq Delta")

ax[0].legend(loc='best')
ax[1].legend(loc='best')

plt.tight_layout()
fig.suptitle("Mortality x Gender",y=1.01)
# Out:
# Text(0.5,1.01,'Mortality x Gender')

# %%
df_delta_long = df_bb_delta_long.append(df_bf_delta_long)
g = sns.catplot(x="metric", y="delta", hue="seed", data=df_delta_long, col="model")
ax1, ax2 = g.axes[0]
ax1.axhline(0, ls='--',c="r")
ax2.axhline(0, ls='--',c="r")
ax1.set_ylim([-LIM,LIM])
ax2.set_ylim([-LIM,LIM])
plt.suptitle("Mortality x Gender")
g

# %% [markdown]
# ## Readmissions

# %%
df = df_readmission
x_label = "TEXT"
y_label = "READMISSION"

results_BOW_M, results_BOW_F = run(df, x_label, y_label, "BOW-bin", "GENDER", "F", split=0.8)
results_BOW_freq_M, results_BOW_freq_F = run(df, x_label, y_label, "BOW-freq", "GENDER", "F", split=0.8)
# Out:
# M: 298 | F: 382
# /Users/samir/anaconda3/lib/python3.6/site-packages/scipy/sparse/lil.py:512: FutureWarning: future versions will not create a writeable array from broadcast_array. Set the writable flag explicitly to avoid this warning.
#   if not i.flags.writeable or i.dtype not in (np.int32, np.int64):
# /Users/samir/anaconda3/lib/python3.6/site-packages/scipy/sparse/lil.py:514: FutureWarning: future versions will not create a writeable array from broadcast_array. Set the writable flag explicitly to avoid this warning.
#   if not j.flags.writeable or j.dtype not in (np.int32, np.int64):
# /Users/samir/anaconda3/lib/python3.6/site-packages/scipy/sparse/lil.py:518: FutureWarning: future versions will not create a writeable array from broadcast_array. Set the writable flag explicitly to avoid this warning.
#   if not x.flags.writeable:
# (sparse BOW)
# (sparse BOW)
# (sparse BOW)
# [running seed: 0]
# ** model: BOW-bin| seed: 0| acc: 0.477| microF1: 0.477| macroF1: 0.465| 0-f1: 0.386| 1-f1: 0.544|
# ** model: BOW-bin| seed: 0| acc: 0.545| microF1: 0.545| macroF1: 0.538| 0-f1: 0.485| 1-f1: 0.592|
# [running seed: 1]
# ** model: BOW-bin| seed: 1| acc: 0.466| microF1: 0.466| macroF1: 0.466| 0-f1: 0.457| 1-f1: 0.475|
# ** model: BOW-bin| seed: 1| acc: 0.555| microF1: 0.555| macroF1: 0.555| 0-f1: 0.55| 1-f1: 0.56|
# [running seed: 2]
# ** model: BOW-bin| seed: 2| acc: 0.52| microF1: 0.52| macroF1: 0.517| 0-f1: 0.555| 1-f1: 0.48|
# /Users/samir/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# ** model: BOW-bin| seed: 2| acc: 0.563| microF1: 0.563| macroF1: 0.561| 0-f1: 0.59| 1-f1: 0.532|
# [running seed: 3]
# ** model: BOW-bin| seed: 3| acc: 0.46| microF1: 0.46| macroF1: 0.449| 0-f1: 0.525| 1-f1: 0.374|
# ** model: BOW-bin| seed: 3| acc: 0.568| microF1: 0.568| macroF1: 0.563| 0-f1: 0.61| 1-f1: 0.516|
# [running seed: 4]
# ** model: BOW-bin| seed: 4| acc: 0.456| microF1: 0.456| macroF1: 0.453| 0-f1: 0.494| 1-f1: 0.413|
# ** model: BOW-bin| seed: 4| acc: 0.55| microF1: 0.55| macroF1: 0.549| 0-f1: 0.563| 1-f1: 0.535|
# [running seed: 5]
# ** model: BOW-bin| seed: 5| acc: 0.483| microF1: 0.483| macroF1: 0.467| 0-f1: 0.374| 1-f1: 0.56|
# ** model: BOW-bin| seed: 5| acc: 0.555| microF1: 0.555| macroF1: 0.55| 0-f1: 0.5| 1-f1: 0.599|
# [running seed: 6]
# ** model: BOW-bin| seed: 6| acc: 0.5| microF1: 0.5| macroF1: 0.5| 0-f1: 0.484| 1-f1: 0.515|
# ** model: BOW-bin| seed: 6| acc: 0.586| microF1: 0.586| macroF1: 0.586| 0-f1: 0.586| 1-f1: 0.586|
# [running seed: 7]
# ** model: BOW-bin| seed: 7| acc: 0.473| microF1: 0.473| macroF1: 0.457| 0-f1: 0.364| 1-f1: 0.55|
# ** model: BOW-bin| seed: 7| acc: 0.579| microF1: 0.579| macroF1: 0.571| 0-f1: 0.517| 1-f1: 0.626|
# [running seed: 8]
# ** model: BOW-bin| seed: 8| acc: 0.513| microF1: 0.513| macroF1: 0.491| 0-f1: 0.598| 1-f1: 0.383|
# ** model: BOW-bin| seed: 8| acc: 0.555| microF1: 0.555| macroF1: 0.535| 0-f1: 0.632| 1-f1: 0.437|
# [running seed: 9]
# ** model: BOW-bin| seed: 9| acc: 0.473| microF1: 0.473| macroF1: 0.438| 0-f1: 0.579| 1-f1: 0.296|
# ** model: BOW-bin| seed: 9| acc: 0.531| microF1: 0.531| macroF1: 0.496| 0-f1: 0.629| 1-f1: 0.363|
# [running seed: 10]
# ** model: BOW-bin| seed: 10| acc: 0.503| microF1: 0.503| macroF1: 0.503| 0-f1: 0.519| 1-f1: 0.486|
# ** model: BOW-bin| seed: 10| acc: 0.547| microF1: 0.547| macroF1: 0.547| 0-f1: 0.562| 1-f1: 0.531|
# [running seed: 11]
# ** model: BOW-bin| seed: 11| acc: 0.453| microF1: 0.453| macroF1: 0.444| 0-f1: 0.513| 1-f1: 0.375|
# ** model: BOW-bin| seed: 11| acc: 0.552| microF1: 0.552| macroF1: 0.547| 0-f1: 0.598| 1-f1: 0.496|
# [running seed: 12]
# ** model: BOW-bin| seed: 12| acc: 0.46| microF1: 0.46| macroF1: 0.459| 0-f1: 0.476| 1-f1: 0.443|
# ** model: BOW-bin| seed: 12| acc: 0.607| microF1: 0.607| macroF1: 0.606| 0-f1: 0.631| 1-f1: 0.581|
# [running seed: 13]
# ** model: BOW-bin| seed: 13| acc: 0.436| microF1: 0.436| macroF1: 0.435| 0-f1: 0.458| 1-f1: 0.413|
# ** model: BOW-bin| seed: 13| acc: 0.576| microF1: 0.576| macroF1: 0.573| 0-f1: 0.609| 1-f1: 0.537|
# [running seed: 14]
# ** model: BOW-bin| seed: 14| acc: 0.49| microF1: 0.49| macroF1: 0.488| 0-f1: 0.453| 1-f1: 0.522|
# ** model: BOW-bin| seed: 14| acc: 0.589| microF1: 0.589| macroF1: 0.588| 0-f1: 0.57| 1-f1: 0.607|
# [running seed: 15]
# ** model: BOW-bin| seed: 15| acc: 0.436| microF1: 0.436| macroF1: 0.425| 0-f1: 0.344| 1-f1: 0.506|
# ** model: BOW-bin| seed: 15| acc: 0.547| microF1: 0.547| macroF1: 0.535| 0-f1: 0.461| 1-f1: 0.609|
# [running seed: 16]
# ** model: BOW-bin| seed: 16| acc: 0.453| microF1: 0.453| macroF1: 0.45| 0-f1: 0.407| 1-f1: 0.492|
# ** model: BOW-bin| seed: 16| acc: 0.547| microF1: 0.547| macroF1: 0.546| 0-f1: 0.523| 1-f1: 0.569|
# [running seed: 17]
# ** model: BOW-bin| seed: 17| acc: 0.483| microF1: 0.483| macroF1: 0.482| 0-f1: 0.454| 1-f1: 0.51|
# ** model: BOW-bin| seed: 17| acc: 0.552| microF1: 0.552| macroF1: 0.552| 0-f1: 0.534| 1-f1: 0.569|
# [running seed: 18]
# ** model: BOW-bin| seed: 18| acc: 0.456| microF1: 0.456| macroF1: 0.456| 0-f1: 0.438| 1-f1: 0.474|
# ** model: BOW-bin| seed: 18| acc: 0.547| microF1: 0.547| macroF1: 0.547| 0-f1: 0.536| 1-f1: 0.558|
# [running seed: 19]
# ** model: BOW-bin| seed: 19| acc: 0.48| microF1: 0.48| macroF1: 0.454| 0-f1: 0.335| 1-f1: 0.573|
# ** model: BOW-bin| seed: 19| acc: 0.592| microF1: 0.592| macroF1: 0.577| 0-f1: 0.5| 1-f1: 0.655|
# M: 298 | F: 382
# (sparse BOW)
# (sparse BOW)
# (sparse BOW)
# [running seed: 0]
# ** model: BOW-freq| seed: 0| acc: 0.453| microF1: 0.453| macroF1: 0.416| 0-f1: 0.269| 1-f1: 0.563|
# ** model: BOW-freq| seed: 0| acc: 0.547| microF1: 0.547| macroF1: 0.516| 0-f1: 0.393| 1-f1: 0.639|
# [running seed: 1]
# ** model: BOW-freq| seed: 1| acc: 0.51| microF1: 0.51| macroF1: 0.426| 0-f1: 0.207| 1-f1: 0.646|
# ** model: BOW-freq| seed: 1| acc: 0.524| microF1: 0.524| macroF1: 0.422| 0-f1: 0.18| 1-f1: 0.664|
# [running seed: 2]
# ** model: BOW-freq| seed: 2| acc: 0.503| microF1: 0.503| macroF1: 0.373| 0-f1: 0.659| 1-f1: 0.086|
# ** model: BOW-freq| seed: 2| acc: 0.516| microF1: 0.516| macroF1: 0.398| 0-f1: 0.664| 1-f1: 0.131|
# [running seed: 3]
# ** model: BOW-freq| seed: 3| acc: 0.47| microF1: 0.47| macroF1: 0.367| 0-f1: 0.112| 1-f1: 0.622|
# ** model: BOW-freq| seed: 3| acc: 0.524| microF1: 0.524| macroF1: 0.419| 0-f1: 0.173| 1-f1: 0.665|
# [running seed: 4]
# ** model: BOW-freq| seed: 4| acc: 0.5| microF1: 0.5| macroF1: 0.496| 0-f1: 0.454| 1-f1: 0.539|
# ** model: BOW-freq| seed: 4| acc: 0.586| microF1: 0.586| macroF1: 0.583| 0-f1: 0.549| 1-f1: 0.618|
# [running seed: 5]
# ** model: BOW-freq| seed: 5| acc: 0.473| microF1: 0.473| macroF1: 0.447| 0-f1: 0.567| 1-f1: 0.326|
# ** model: BOW-freq| seed: 5| acc: 0.542| microF1: 0.542| macroF1: 0.529| 0-f1: 0.607| 1-f1: 0.451|
# [running seed: 6]
# ** model: BOW-freq| seed: 6| acc: 0.473| microF1: 0.473| macroF1: 0.422| 0-f1: 0.594| 1-f1: 0.249|
# ** model: BOW-freq| seed: 6| acc: 0.495| microF1: 0.495| macroF1: 0.458| 0-f1: 0.599| 1-f1: 0.318|
# [running seed: 7]
# ** model: BOW-freq| seed: 7| acc: 0.503| microF1: 0.503| macroF1: 0.352| 0-f1: 0.665| 1-f1: 0.039|
# ** model: BOW-freq| seed: 7| acc: 0.5| microF1: 0.5| macroF1: 0.347| 0-f1: 0.663| 1-f1: 0.03|
# [running seed: 8]
# ** model: BOW-freq| seed: 8| acc: 0.497| microF1: 0.497| macroF1: 0.338| 0-f1: 0.013| 1-f1: 0.662|
# ** model: BOW-freq| seed: 8| acc: 0.497| microF1: 0.497| macroF1: 0.341| 0-f1: 0.02| 1-f1: 0.662|
# [running seed: 9]
# ** model: BOW-freq| seed: 9| acc: 0.5| microF1: 0.5| macroF1: 0.339| 0-f1: 0.665| 1-f1: 0.013|
# ** model: BOW-freq| seed: 9| acc: 0.505| microF1: 0.505| macroF1: 0.349| 0-f1: 0.668| 1-f1: 0.031|
# [running seed: 10]
# ** model: BOW-freq| seed: 10| acc: 0.477| microF1: 0.477| macroF1: 0.475| 0-f1: 0.5| 1-f1: 0.451|
# ** model: BOW-freq| seed: 10| acc: 0.552| microF1: 0.552| macroF1: 0.552| 0-f1: 0.546| 1-f1: 0.558|
# [running seed: 11]
# ** model: BOW-freq| seed: 11| acc: 0.477| microF1: 0.477| macroF1: 0.438| 0-f1: 0.291| 1-f1: 0.585|
# ** model: BOW-freq| seed: 11| acc: 0.513| microF1: 0.513| macroF1: 0.471| 0-f1: 0.321| 1-f1: 0.62|
# [running seed: 12]
# ** model: BOW-freq| seed: 12| acc: 0.44| microF1: 0.44| macroF1: 0.423| 0-f1: 0.521| 1-f1: 0.324|
# ** model: BOW-freq| seed: 12| acc: 0.542| microF1: 0.542| macroF1: 0.529| 0-f1: 0.607| 1-f1: 0.451|
# [running seed: 13]
# ** model: BOW-freq| seed: 13| acc: 0.49| microF1: 0.49| macroF1: 0.351| 0-f1: 0.05| 1-f1: 0.651|
# ** model: BOW-freq| seed: 13| acc: 0.497| microF1: 0.497| macroF1: 0.354| 0-f1: 0.05| 1-f1: 0.658|
# [running seed: 14]
# ** model: BOW-freq| seed: 14| acc: 0.473| microF1: 0.473| macroF1: 0.429| 0-f1: 0.588| 1-f1: 0.27|
# ** model: BOW-freq| seed: 14| acc: 0.581| microF1: 0.581| macroF1: 0.539| 0-f1: 0.679| 1-f1: 0.398|
# [running seed: 15]
# ** model: BOW-freq| seed: 15| acc: 0.53| microF1: 0.53| macroF1: 0.456| 0-f1: 0.255| 1-f1: 0.657|
# ** model: BOW-freq| seed: 15| acc: 0.547| microF1: 0.547| macroF1: 0.478| 0-f1: 0.288| 1-f1: 0.668|
# [running seed: 16]
# ** model: BOW-freq| seed: 16| acc: 0.46| microF1: 0.46| macroF1: 0.443| 0-f1: 0.348| 1-f1: 0.539|
# ** model: BOW-freq| seed: 16| acc: 0.542| microF1: 0.542| macroF1: 0.525| 0-f1: 0.434| 1-f1: 0.615|
# [running seed: 17]
# ** model: BOW-freq| seed: 17| acc: 0.5| microF1: 0.5| macroF1: 0.333| 0-f1: 0.0| 1-f1: 0.667|
# ** model: BOW-freq| seed: 17| acc: 0.5| microF1: 0.5| macroF1: 0.333| 0-f1: 0.0| 1-f1: 0.667|
# [running seed: 18]
# ** model: BOW-freq| seed: 18| acc: 0.483| microF1: 0.483| macroF1: 0.366| 0-f1: 0.638| 1-f1: 0.094|
# ** model: BOW-freq| seed: 18| acc: 0.518| microF1: 0.518| macroF1: 0.419| 0-f1: 0.659| 1-f1: 0.179|
# [running seed: 19]
# ** model: BOW-freq| seed: 19| acc: 0.466| microF1: 0.466| macroF1: 0.412| 0-f1: 0.591| 1-f1: 0.232|
# ** model: BOW-freq| seed: 19| acc: 0.521| microF1: 0.521| macroF1: 0.48| 0-f1: 0.626| 1-f1: 0.335|
# /Users/samir/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/samir/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/samir/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/samir/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## Results

# %%
#results
df_bb_delta, df_bb_delta_long = get_deltas(results_BOW_M,results_BOW_F)
df_bf_delta, df_bf_delta_long = get_deltas(results_BOW_freq_M,results_BOW_freq_F)

# %% [markdown]
# ## Plots

# %%
fig, ax = plt.subplots(1,2, sharey=True, figsize=(15,5))
LIM = 0.25
plots.plot_df(df=df_bb_delta,ax=ax[0],x="seed",ys=["microF1","macroF1","1-f1","0-f1"], annotation_size=10, max_y=LIM, min_y=-LIM)
plots.plot_df(df=df_bf_delta,ax=ax[1],x="seed",ys=["microF1","macroF1","1-f1","0-f1"], annotation_size=10, max_y=LIM, min_y=-LIM)

ax[0].set_title("bow-bin Delta")
ax[1].set_title("bow-freq Delta")

ax[0].legend(loc='best')
ax[1].legend(loc='best')

plt.tight_layout()
fig.suptitle("Readmissions x Gender",y=1.01)
# Out:
# Text(0.5,1.01,'Readmissions x Gender')

# %%
df_delta_long = df_bb_delta_long.append(df_bf_delta_long)
g = sns.catplot(x="metric", y="delta", hue="seed", data=df_delta_long, col="model")
ax1, ax2 = g.axes[0]
ax1.axhline(0, ls='--',c="r")
ax2.axhline(0, ls='--',c="r")
ax1.set_ylim([-LIM,LIM])
ax2.set_ylim([-LIM,LIM])
plt.suptitle("Readmissions x Gender")
g
